# %% [markdown]
# # Cleaning Data with Pandas Exercises
#
# For the exercises, you will be cleaning data in the Women's Clothing E-Commerce Reviews dataset.
#
# To start cleaning data, we first need to create a dataframe from the CSV and print out any relevant info to make sure our dataframe is ready to go.

# %%
# Import pandas and any other libraries you need here.
import pandas as pd

clothing = pd.read_csv('WomensClothingE-CommerceReviews.csv')

# Create a new dataframe from your CSV

# %%
# Print out any information you need to understand your dataframe
clothing.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
clothing.shape
# Out:
# (23486, 11)

# %%
clothing.columns
# Out:
# Index(['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name'],
#       dtype='object')

# %%
clothing.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# ...

# %% [markdown]
# ## Missing Data
#
# Try out different methods to locate and resolve missing data.

# %%
# Try to find some missing data!
#starting with some basic pandas functions for a count of nulls
clothing.isnull().sum()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
clothing.isna()
# Out:
#        Unnamed: 0  Clothing ID    Age  Title  Review Text  Rating  \
# 0           False        False  False   True        False   False
# 1           False        False  False   True        False   False
# 2           False        False  False  False        False   False
# 3           False        False  False  False        False   False
# 4           False        False  False  False        False   False
# ...           ...          ...    ...    ...          ...     ...
# 23481       False        False  False  False        False   False
# 23482       False        False  False  False        False   False
# 23483       False        False  False  False        False   False
# 23484       False        False  False  False        False   False
# 23485       False        False  False  False        False   False
#
#        Recommended IND  Positive Feedback Count  Division Name  \
# 0                False                    False          False
# ...

# %%
clothing.dropna(how="all")
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %%
cols = {'Division Name': 'no entry', 'Department Name': 'no eentry', 'Class Name': 'no entry' }
clothing.fillna(value=cols)
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %%
clothing_new = clothing.copy()
print(clothing_new)
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# ...

# %% [markdown]
# Did you find any missing data? What things worked well for you and what did not?

# %%
# Respond to the above questions here:
# isnull().sum() was helpful for an broad overview. 
# title, review text each have a lot of missing values. seeing that each of the division, department, and class name each have 14 missing values indicates something specific might be going on with those 14 records. 
#there were no rows full empty to drop, which I could tell because the total number of rows in the output stayed the same, so not full rows/records were null in this dataset. 
#based on the data I can see, I don't think it's safe to delte any whole columns. The dataset only has 11 columns, and while title is missing a lot of values, those are user-entered values from customers and the review and title in combination seem like they provide a lot of qualitative informaiton that may be necessary later. 
# Since I'm not sure if we're analyzing for the quantitative data specifically, I don't want to remove anything taht might be necessary later, and only 14 null values in other columns isn't much to worry about. 
# The columns that have the missing values in only 14 entrees don't seem impactful enough to eleminate the entire record, so it doesn't seem necessary to remove the data. 
#I used fillna to place a 0 in the cells for those 3 columns.

# %% [markdown]
# ## Irregular Data
#
# With missing data out of the way, turn your attention to any outliers. Just as we did for missing data, we first need to detect the outliers.

# %%
# Keep an eye out for outliers!
clothing.describe
# Out:
#          Unnamed: 0   Clothing ID           Age        Rating  \
# count  23486.000000  23486.000000  23486.000000  23486.000000
# mean   11742.500000    918.118709     43.198544      4.196032
# std     6779.968547    203.298980     12.279544      1.110031
# min        0.000000      0.000000     18.000000      1.000000
# 25%     5871.250000    861.000000     34.000000      4.000000
# 50%    11742.500000    936.000000     41.000000      5.000000
# 75%    17613.750000   1078.000000     52.000000      5.000000
# max    23485.000000   1205.000000     99.000000      5.000000
#
#        Recommended IND  Positive Feedback Count
# count     23486.000000             23486.000000
# mean          0.822362                 2.535936
# std           0.382216                 5.702202
# min           0.000000                 0.000000
# 25%           1.000000                 0.000000
# 50%           1.000000                 1.000000
# 75%           1.000000                 3.000000
# ...

# %%
pip install matplotlib
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    -------- ------------------------------- 1.6/7.8 MB 8.4 MB/s eta 0:00:01
#    -------------------- ------------------- 3.9/7.8 MB 10.2 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/7.8 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 9.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------------------------------- ------ 1.8/2.2 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 8.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------------- ------------------- 1.3/2.6 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 8.1 MB/s eta 0:00:00
# ...

# %%
import matplotlib as plot
clothing.plot.hist(column="Clothing ID")
# Out:
# <Axes: ylabel='Frequency'>

# %%
clothing.plot.hist(column="Age")
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np

# %%
# outlier = np.where((etsy_sellers['Total_Rating'] < 0.0) & (etsy_sellers['Total_Rating'] > 5.0))
# etsy_sellers.drop(etsy_sellers[outlier])

# %% [markdown]
# What techniques helped you find outliers? In your opinion, what about the techniques you used made them effective?

# %%
# Make your notes here:
# The age max is 99, which seems unlikely. 
# Also, that a clothing ID would be 0 as the minimum seems incorrect. a clothing ID wouldn't be zero as a unique identifier.
# investigating using .describe() was a really easy overview of the data for a quick read, especially since there are a limited number of columns with quantitative data in them in this dataset. 
# Based on the histogram of age, I'm going to eliminate any responses from ages above 79 because there is so little data that high in age and it will remove the really high end outliers. I'm only going to eliminate the 000 from Clothing ID ebcause I think that's an error in reporting the clothing ID.

# %% [markdown]
# ## Unnecessary Data
#
# Unnecessary data could be irrelevant to your analysis or a duplice column. Check out the dataset to see if there is any unnecessary data.

# %%
# Look out for unnecessary data!

# %% [markdown]
# Did you find any unnecessary data in your dataset? How did you handle it?

# %%
# Make your notes here.
# the "Unnamed" column looks like it's the same as the index column, so it's not necessary to have both of them present. 
# wihtout any more informaiton about the business issue, I can't assess if any other information is unecessary.

# %% [markdown]
# ## Inconsistent Data
#
# Inconsistent data is likely due to inconsistent formatting and can be addressed by re-formatting all values in a column or row.

# %%
# Look out for inconsistent data!

# %%
clothing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
clothing['Title'].apply(type).value_counts()
# Out:
# Title
# <class 'str'>      19676
# <class 'float'>     3810
# Name: count, dtype: int64

# %%
clothing['Review Text'].apply(type).value_counts()
# Out:
# Review Text
# <class 'str'>      22641
# <class 'float'>      845
# Name: count, dtype: int64

# %%
clothing['Division Name'].apply(type).value_counts()
# Out:
# Division Name
# <class 'str'>      23472
# <class 'float'>       14
# Name: count, dtype: int64

# %%
clothing['Department Name'].apply(type).value_counts()
# Out:
# Department Name
# <class 'str'>      23472
# <class 'float'>       14
# Name: count, dtype: int64

# %%
clothing['Class Name'].apply(type).value_counts()
# Out:
# Class Name
# <class 'str'>      23472
# <class 'float'>       14
# Name: count, dtype: int64

# %% [markdown]
# Did you find any inconsistent data? What did you do to clean it?

# %%
# Make your notes here!
# the inconsistent data based on datatypes all aligned with the null value quantities from the missing data.
# If I'd successfully eliminated or replaced those with differnet values, it would ahve eliminated any inconsistences in datatypes in the dataframe.
